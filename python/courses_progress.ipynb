# %% [markdown]
# See link https://www.bgsu.edu/graduate/catalogs-and-policies/graduate-catalog/data-science.html

# %%
import pandas as pd
import numpy as np

# %%
# requirements
req = pd.read_csv("../data//corses_list.csv")
req = req.iloc[:,1:4]

# %%
req["type"] = ""
req.loc[:14, "type"] = "required"
req.loc[15:46, "type"] = "electives"
# req.set_index("Code", inplace=True)

# %% [markdown]
# ## Transripts

# %%
def parse_transcript(F, name, old_req):
    df =  [[
        a.split()[0]+"_"+a.split()[1], a.split()[-2]
    ] for a in F.splitlines() if len(a)>0]
    df = pd.DataFrame(df)
    df.columns = ["Code", name]
    new_req = pd.merge(old_req, df, on="Code", how = "left")
    return new_req

# %%
fall_2020 = """
CS 5620 Database Mgmt Systems 3.000 3.000 B 9.000
CS 6010 Data Science Programming 3.000 3.000 A 12.000
MATH 6410 Probability Theory I 3.000 3.000 A 12.000
OR 6610 Linear-Integer Prgmg 3.000 3.000 A 12.000
"""

req = parse_transcript(fall_2020, "Fall_2020", old_req=req)

# %%
dat = """
MATH 6420 Math Statistics II 3.000 3.000 A 12.000
STAT 5160 Time Series Analysis 3.000 3.000 A 12.000
STAT 6440 Data Mining 3.000 3.000 A 12.000
"""
req = parse_transcript(dat, "Spring_2021", old_req=req)

# %%
dat = """
DATA 6910 Data Science Project 3.000 3.000 S 0.000
MATH 6570 Statistical Computing 3.000 3.000 A 12.000
STAT 5020 Regression Analysis 3.000 3.000 A 12.000
"""
req = parse_transcript(dat, "Fall_2021", old_req=req)

# %%
dat = """
CS 6500 Big Data Analytics 3.000 3.000 A 12.000
MATH 6820 Topics In Math or Stat 3.000 3.000 A 12.000
MATH 7590 Gen Linear Models 3.000 3.000 A 12.000
"""
req = parse_transcript(dat, "Spring_2022", old_req=req)

# %%
dat = """
CS 5170 Intro Parallel Computing 3.000 3.000 A 12.000
CS 7300 Unsupervised Feature Learning 3.000 3.000 A 12.000
MATH 6490 Statistical Graphics 3.000 3.000 A 12.000
"""
req = parse_transcript(dat, "Fall_2022", old_req=req)

# %%
dat = """
CS 5630 Python for Comput & Data Sci 3.000 3.000 A 12.000
STAT 7440 Adv Topics in Data Mining 3.000 3.000 A 12.000
PHIL 6400 Data Science Ethics 3.000 3.000 A 12.000
"""
req = parse_transcript(dat, "Spring_2023", old_req=req)

# %%
dat = """
DATA 7770 Data Science Exploration 1.000 0.000 IP 0.000
MATH 6440 Stochastic Processes 3.000 0.000 IP 0.000
MATH 6480 Bayesian Decision Theory 3.000 0.000 IP 0.000
MATH 7570 Linear Stat Inference 3.000 0.000 IP 0.000
"""
req=parse_transcript(dat, "Fall_2023", old_req=req)

# %% [markdown]
# ## Analysis

# %%
grade_columns = np.array([c for c in req.columns if "_" in c])
ms_grade_columns = grade_columns[:3]
phd_grade_columns = grade_columns[3:]

# %% [markdown]
# ## Export

# %%
long_req = pd.melt(req, 
        id_vars=["Code", "Name","Credits","type"], value_vars=grade_columns, var_name="season",value_name="grade")
long_req["year_half"] = long_req.season.str.split("_").str.get(0)
long_req["year"] = long_req.season.str.split("_").str.get(1).astype("int")
grade_dict = {"A":4,"B":3,"C":2, "D":1,"F":0,np.nan:0}
long_req["number_grade"] = long_req["grade"].map(grade_dict)
long_req = long_req[~long_req["grade"].isna()]

# %%
long_req["Lector"] = np.nan
long_req.loc[long_req["Code"]=="OR_6610", "Lector"] = "Christopher Rump"
long_req.loc[long_req["Code"]=="STAT_6440", "Lector"] = "Shuchismita Sarkar"
long_req.loc[long_req["Code"]=="CS_6010", "Lector"] = "Robert C. Green II"
long_req.loc[long_req["Code"]=="CS_7300", "Lector"] = "Qing Tian"
long_req.loc[long_req["Code"]=="MATH_6490", "Lector"] = "Junfeng Shang"
long_req.loc[long_req["Code"]=="CS_5630", "Lector"] = "Qing Tian"
long_req.loc[long_req["Code"]=="STAT_7440", "Lector"] = "Trent D. Buskirk"
long_req.loc[long_req["Code"]=="PHIL_6400", "Lector"] = "Justin Donhauser"
long_req.loc[long_req["Code"]=="CS_5620", "Lector"] = "Ray Kresman"
long_req.loc[long_req["Code"]=="MATH_6410", "Lector"] = "Wei Ning"
long_req.loc[long_req["Code"]=="MATH_6420", "Lector"] = "Wei Ning"
long_req.loc[long_req["Code"]=="STAT_5160", "Lector"] = "Yuhang Xu"
long_req.loc[long_req["Code"]=="MATH_6570", "Lector"] = "Maria Rizzo"
long_req.loc[long_req["Code"]=="STAT_5020", "Lector"] = "Shuchismita Sarkar"
long_req.loc[long_req["Code"]=="DATA_6910", "Lector"] = "Yuhang Xu"
long_req.loc[long_req["Code"]=="CS_6500", "Lector"] = "Shuteng Niu"
long_req.loc[long_req["Code"]=="MATH_7590", "Lector"] = "Hanfeng Chen"
long_req.loc[long_req["Code"]=="MATH_6820", "Lector"] = "Craig Zirbel"
long_req.loc[long_req["Code"]=="CS_5170", "Lector"] = "Robert C. Green II"
long_req.loc[long_req["Code"]=="MATH_6440", "Lector"] = "Craig Zirbel"
long_req.loc[long_req["Code"]=="MATH_6480", "Lector"] = "Wei Ning"
long_req.loc[long_req["Code"]=="MATH_7570", "Lector"] = "Junfeng Shang"
long_req.loc[long_req["Code"]=="DATA_6910", "Name"] = "MS Thesis"
long_req.loc[long_req["Code"]=="DATA_6910", "Credits"] = 3
long_req.loc[long_req["Code"]=="DATA_6910", "type"] = "required"
#long_req.loc[long_req["Code"]=="???", "Lector"] = "???"
print(f'{long_req["Lector"].isna().sum()} Nans')
long_req[long_req["Lector"].isna()]
# Out:
# 1 Nans
#           Code                      Name  Credits      type     season grade  \
# 290  DATA_7770  Data Science Exploration      1.0  required  Fall_2023    IP
#
#     year_half  year  number_grade Lector
# 290      Fall  2023           NaN    NaN

# %%
long_req["Subject"] = long_req["Code"].str.split("_").str.get(0)

# %%
long_req.to_csv("../data//long_list_raw.csv", index=False)

# %%
long_req
# Out:
#           Code                                               Name  Credits  \
# 17     CS_5620                        Database Management Systems      3.0
# 18     CS_6010                           Data Science Programming      3.0
# 25   MATH_6410                               Probability Theory I      3.0
# 39     OR_6610                     Linear and Integer Programming      3.0
# 73   MATH_6420                         Mathematical Statistics II      3.0
# 89   STAT_5160                               Time Series Analysis      3.0
# 92   STAT_6440                                        Data Mining      3.0
# 126  MATH_6570                        Statistical Computing (new)      3.0
# 135  STAT_5020                                Regression Analysis      3.0
# 143    CS_6500                                 Big Data Analytics      3.0
# 148  MATH_7590                          Gen Linear Models and Ext      3.0
# 176  MATH_6820  Topics in Mathematics or Statistics, with advi...      3.0
# 191    CS_7300                      Unsupervised Feature Learning      3.0
# 203    CS_5170                 Introduction to Parallel Computing      3.0
# 219  MATH_6490                         Statistical Graphics (new)      3.0
# 245  PHIL_6400                     Ethical Issues in Data Science      3.0
# 246  STAT_7440                               Advanced Data Mining      3.0
# 258    CS_5630         Python for Computational and Data Sciences      3.0
# 288  MATH_7570                              Linear Stat Inference      3.0
# 290  DATA_7770                           Data Science Exploration      1.0
# 309  MATH_6440                               Stochastic Processes      3.0
# 312  MATH_6480                     Bayesian Statistical Inference      3.0
#
#           type       season grade year_half  year  number_grade  \
# 17   electives    Fall_2020     B      Fall  2020           3.0
# 18   electives    Fall_2020     A      Fall  2020           4.0
# 25   electives    Fall_2020     A      Fall  2020           4.0
# 39   electives    Fall_2020     A      Fall  2020           4.0
# 73   electives  Spring_2021     A    Spring  2021           4.0
# 89   electives  Spring_2021     A    Spring  2021           4.0
# 92   electives  Spring_2021     A    Spring  2021           4.0
# 126  electives    Fall_2021     A      Fall  2021           4.0
# 135  electives    Fall_2021     A      Fall  2021           4.0
# 143   required  Spring_2022     A    Spring  2022           4.0
# 148   required  Spring_2022     A    Spring  2022           4.0
# 176  electives  Spring_2022     A    Spring  2022           4.0
# 191   required    Fall_2022     A      Fall  2022           4.0
# 203  electives    Fall_2022     A      Fall  2022           4.0
# 219  electives    Fall_2022     A      Fall  2022           4.0
# 245   required  Spring_2023     A    Spring  2023           4.0
# 246   required  Spring_2023     A    Spring  2023           4.0
# 258  electives  Spring_2023     A    Spring  2023           4.0
# 288   required    Fall_2023    IP      Fall  2023           NaN
# 290   required    Fall_2023    IP      Fall  2023           NaN
# 309  electives    Fall_2023    IP      Fall  2023           NaN
# 312  electives    Fall_2023    IP      Fall  2023           NaN
#
#                  Lector Subject
# 17          Ray Kresman      CS
# 18   Robert C. Green II      CS
# 25             Wei Ning    MATH
# 39     Christopher Rump      OR
# 73             Wei Ning    MATH
# 89            Yuhang Xu    STAT
# 92   Shuchismita Sarkar    STAT
# 126         Maria Rizzo    MATH
# 135  Shuchismita Sarkar    STAT
# 143         Shuteng Niu      CS
# 148        Hanfeng Chen    MATH
# 176        Craig Zirbel    MATH
# 191           Qing Tian      CS
# 203  Robert C. Green II      CS
# 219       Junfeng Shang    MATH
# 245    Justin Donhauser    PHIL
# 246    Trent D. Buskirk    STAT
# 258           Qing Tian      CS
# 288       Junfeng Shang    MATH
# 290                 NaN    DATA
# 309        Craig Zirbel    MATH
# 312            Wei Ning    MATH

# %% [markdown]
# ## Analysis

# %%
long_req = pd.read_csv("../data/long_list_raw.csv")
len(long_req)
# Out:
# 22

# %%
type_cp = ["required"]
int(long_req[(long_req["type"].isin(type_cp)) & (~long_req["grade"].isna())]["Credits"].sum())
# Out:
# 19

# %%
subj = long_req["Code"].str.split("_").str.get(0).unique()
subj = ["CS"]

# %%
dff = long_req
dff[dff["Code"].str.split("_").str.get(0).isin(subj)]
# Out:
#        Code                                        Name  Credits       type  \
# 0   CS_5620                 Database Management Systems      3.0  electives
# 1   CS_6010                    Data Science Programming      3.0  electives
# 9   CS_6500                          Big Data Analytics      3.0   required
# 12  CS_7300               Unsupervised Feature Learning      3.0   required
# 13  CS_5170          Introduction to Parallel Computing      3.0  electives
# 17  CS_5630  Python for Computational and Data Sciences      3.0  electives
#
#          season grade year_half  year  number_grade              Lector  \
# 0     Fall_2020     B      Fall  2020           3.0         Ray Kresman
# 1     Fall_2020     A      Fall  2020           4.0  Robert C. Green II
# 9   Spring_2022     A    Spring  2022           4.0         Shuteng Niu
# 12    Fall_2022     A      Fall  2022           4.0           Qing Tian
# 13    Fall_2022     A      Fall  2022           4.0  Robert C. Green II
# 17  Spring_2023     A    Spring  2023           4.0           Qing Tian
#
#    Subject
# 0       CS
# 1       CS
# 9       CS
# 12      CS
# 13      CS
# 17      CS

# %%
ms_courses = long_req[
    (long_req["season"].isin(ms_grade_columns)) &
    (~long_req["grade"].isna())
].fillna(0)
ms_gpa = sum(ms_courses["Credits"]*ms_courses["number_grade"])/sum(ms_courses["Credits"])
print("MS Courses: GPS=", np.round(ms_gpa, 3))
ms_courses
# Out:
# MS Courses: GPS= 3.889
#         Code                            Name  Credits       type       season  \
# 0    CS_5620     Database Management Systems      3.0  electives    Fall_2020
# 1    CS_6010        Data Science Programming      3.0  electives    Fall_2020
# 2  MATH_6410            Probability Theory I      3.0  electives    Fall_2020
# 3    OR_6610  Linear and Integer Programming      3.0  electives    Fall_2020
# 4  MATH_6420      Mathematical Statistics II      3.0  electives  Spring_2021
# 5  STAT_5160            Time Series Analysis      3.0  electives  Spring_2021
# 6  STAT_6440                     Data Mining      3.0  electives  Spring_2021
# 7  MATH_6570     Statistical Computing (new)      3.0  electives    Fall_2021
# 8  STAT_5020             Regression Analysis      3.0  electives    Fall_2021
#
#   grade year_half  year  number_grade              Lector Subject
# 0     B      Fall  2020           3.0         Ray Kresman      CS
# 1     A      Fall  2020           4.0  Robert C. Green II      CS
# 2     A      Fall  2020           4.0            Wei Ning    MATH
# 3     A      Fall  2020           4.0    Christopher Rump      OR
# 4     A    Spring  2021           4.0            Wei Ning    MATH
# 5     A    Spring  2021           4.0           Yuhang Xu    STAT
# 6     A    Spring  2021           4.0  Shuchismita Sarkar    STAT
# 7     A      Fall  2021           4.0         Maria Rizzo    MATH
# 8     A      Fall  2021           4.0  Shuchismita Sarkar    STAT

# %%
phd_courses = long_req[
    (long_req["season"].isin(phd_grade_columns)) &
    (~long_req["grade"].isna())
].dropna()
phd_gpa = sum(phd_courses["Credits"]*phd_courses["number_grade"])/sum(phd_courses["Credits"])
print("MS Courses: GPA=", np.round(phd_gpa, 3))
phd_courses
# Out:
# MS Courses: GPA= 4.0
#          Code                                               Name  Credits  \
# 9     CS_6500                                 Big Data Analytics      3.0
# 10  MATH_7590                          Gen Linear Models and Ext      3.0
# 11  MATH_6820  Topics in Mathematics or Statistics, with advi...      3.0
# 12    CS_7300                      Unsupervised Feature Learning      3.0
# 13    CS_5170                 Introduction to Parallel Computing      3.0
# 14  MATH_6490                         Statistical Graphics (new)      3.0
# 15  PHIL_6400                     Ethical Issues in Data Science      3.0
# 16  STAT_7440                               Advanced Data Mining      3.0
# 17    CS_5630         Python for Computational and Data Sciences      3.0
#
#          type       season grade year_half  year  number_grade  \
# 9    required  Spring_2022     A    Spring  2022           4.0
# 10   required  Spring_2022     A    Spring  2022           4.0
# 11  electives  Spring_2022     A    Spring  2022           4.0
# 12   required    Fall_2022     A      Fall  2022           4.0
# 13  electives    Fall_2022     A      Fall  2022           4.0
# 14  electives    Fall_2022     A      Fall  2022           4.0
# 15   required  Spring_2023     A    Spring  2023           4.0
# 16   required  Spring_2023     A    Spring  2023           4.0
# 17  electives  Spring_2023     A    Spring  2023           4.0
#
#                 Lector Subject
# 9          Shuteng Niu      CS
# 10        Hanfeng Chen    MATH
# 11        Craig Zirbel    MATH
# 12           Qing Tian      CS
# 13  Robert C. Green II      CS
# 14       Junfeng Shang    MATH
# 15    Justin Donhauser    PHIL
# 16    Trent D. Buskirk    STAT
# 17           Qing Tian      CS

# %%
phd_required = long_req[
     (long_req["season"].isin(phd_grade_columns)) &
     (long_req["type"] == "required") &
     (~long_req["grade"].isna())
]
print("Required:", phd_required["Credits"].sum())
phd_required
# Out:
# Required: 19.0
#          Code                            Name  Credits      type       season  \
# 9     CS_6500              Big Data Analytics      3.0  required  Spring_2022
# 10  MATH_7590       Gen Linear Models and Ext      3.0  required  Spring_2022
# 12    CS_7300   Unsupervised Feature Learning      3.0  required    Fall_2022
# 15  PHIL_6400  Ethical Issues in Data Science      3.0  required  Spring_2023
# 16  STAT_7440            Advanced Data Mining      3.0  required  Spring_2023
# 18  MATH_7570           Linear Stat Inference      3.0  required    Fall_2023
# 19  DATA_7770        Data Science Exploration      1.0  required    Fall_2023
#
#    grade year_half  year  number_grade            Lector Subject
# 9      A    Spring  2022           4.0       Shuteng Niu      CS
# 10     A    Spring  2022           4.0      Hanfeng Chen    MATH
# 12     A      Fall  2022           4.0         Qing Tian      CS
# 15     A    Spring  2023           4.0  Justin Donhauser    PHIL
# 16     A    Spring  2023           4.0  Trent D. Buskirk    STAT
# 18    IP      Fall  2023           NaN     Junfeng Shang    MATH
# 19    IP      Fall  2023           NaN               NaN    DATA

# %%
phd_electives = long_req[
     (long_req["season"].isin(phd_grade_columns)) &
     (long_req["type"] == "electives") &
     (~long_req["grade"].isna())
]
print("Electives:", phd_electives["Credits"].sum())
phd_electives
# Out:
# Electives: 18.0
#          Code                                               Name  Credits  \
# 11  MATH_6820  Topics in Mathematics or Statistics, with advi...      3.0
# 13    CS_5170                 Introduction to Parallel Computing      3.0
# 14  MATH_6490                         Statistical Graphics (new)      3.0
# 17    CS_5630         Python for Computational and Data Sciences      3.0
# 20  MATH_6440                               Stochastic Processes      3.0
# 21  MATH_6480                     Bayesian Statistical Inference      3.0
#
#          type       season grade year_half  year  number_grade  \
# 11  electives  Spring_2022     A    Spring  2022           4.0
# 13  electives    Fall_2022     A      Fall  2022           4.0
# 14  electives    Fall_2022     A      Fall  2022           4.0
# 17  electives  Spring_2023     A    Spring  2023           4.0
# 20  electives    Fall_2023    IP      Fall  2023           NaN
# 21  electives    Fall_2023    IP      Fall  2023           NaN
#
#                 Lector Subject
# 11        Craig Zirbel    MATH
# 13  Robert C. Green II      CS
# 14       Junfeng Shang    MATH
# 17           Qing Tian      CS
# 20        Craig Zirbel    MATH
# 21            Wei Ning    MATH

# %%
long_req[(long_req["season"]=="Fall_2023") & (~long_req["grade"].isna()) ]
# Out:
#          Code                            Name  Credits       type     season  \
# 18  MATH_7570           Linear Stat Inference      3.0   required  Fall_2023
# 19  DATA_7770        Data Science Exploration      1.0   required  Fall_2023
# 20  MATH_6440            Stochastic Processes      3.0  electives  Fall_2023
# 21  MATH_6480  Bayesian Statistical Inference      3.0  electives  Fall_2023
#
#    grade year_half  year  number_grade         Lector Subject
# 18    IP      Fall  2023           NaN  Junfeng Shang    MATH
# 19    IP      Fall  2023           NaN            NaN    DATA
# 20    IP      Fall  2023           NaN   Craig Zirbel    MATH
# 21    IP      Fall  2023           NaN       Wei Ning    MATH
